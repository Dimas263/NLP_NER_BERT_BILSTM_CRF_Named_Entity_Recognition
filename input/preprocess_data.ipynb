# %% [markdown]
# # <img src="https://img.icons8.com/external-flaticons-lineal-color-flat-icons/64/undefined/external-big-data-smart-technology-flaticons-lineal-color-flat-icons-2.png"/> **NLP Research <br>Data Preprocessing Named Entity Recognition**
# ## <img src="https://img.icons8.com/external-fauzidea-flat-fauzidea/64/undefined/external-man-avatar-avatar-fauzidea-flat-fauzidea.png"/> **`Dimas Dwi Putra`**

# %% [markdown]
# # **Connect google drive storage**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# # **Data preprocessing**

# %% [markdown]
# ## **Original dataset `gold-standard-corpus.xlsx`**

# %%
pd.read_excel("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/ori_data/gold-standard-corpus.xlsx")
# Out:
#             pmid title/abstract  sentence_id  \
# 0      1182944.0              t          0.0
# 1      1182944.0              a          0.0
# 2      1182944.0              a          5.0
# 3      1423310.0              t          0.0
# 4      1423310.0              a          0.0
# ...          ...            ...          ...
# 1302  24957864.0              a          3.0
# 1303  24957864.0              a          3.0
# 1304  24957864.0              a          4.0
# 1305  24957864.0              a          6.0
# 1306  24957864.0              a          6.0
#
#                                                sentence      plant  \
# 0     Studies on magnesium's mechanism of action in ...  digitalis
# 1     The mechanism by which magnesium affects digit...  digitalis
# 2     Magnesium's direct effect on calcium and potas...  digitalis
# 3     Inhibitory effect of green tea on the growth o...  green tea
# 4     In 10 separate experiments, mice with establis...  green tea
# ...

# %% [markdown]
# ## **Convert excel `gold-standard-corpus.xlsx` to `annotated-plant-disease-corpus`**

# %%
! python "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/data/data_preprocessing.py"
# Out:
# success converting gold-standard-corpus.xlsx to annotated-dataset-plant-disease-corpus.txt

# %%
! ls -lh "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/data"
# Out:
# total 465K
# -rw------- 1 root root 336K Jun 26 04:36 annotated-dataset-plant-disease-corpus.txt
# -rw------- 1 root root 1.4K Jun 25 20:52 data_preprocessing.py
# -rw------- 1 root root 128K Jun 12 16:28 gold-standard-corpus.xlsx

# %% [markdown]
# ## **Convert `annotated dataset` to `BIO Dataset`**

# %%
! python "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/preprocess.py"

# %%
! ls -lh "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/BIO"
# Out:
# total 1.4M
# -rw------- 1 root root 344K Jun 26 04:36 BIO.txt
# -rw------- 1 root root 342K Jun 26 04:36 enimex.txt
# -rw------- 1 root root 326K Jun 26 04:36 final-data.txt
# -rw------- 1 root root 393K Jun 26 04:36 stanford.txt

# %% [markdown]
# ### **Read BIO Dataset**

# %%
bio_dataset = open("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/BIO/final-data.txt", "r")
print(bio_dataset.read())
# Out:
# studies	O
# on	O
# magnesium s	O
# mechanism	O
# of	O
# action	O
# in	O
# digitalis	B-plant
# induced	O
# arrhythmias	B-disease
#
# the	O
# mechanism	O
# by	O
# which	O
# magnesium	O
# affects	O
# digitalis	B-plant
# induced	O
# arrhythmias	B-disease
# was	O
# studied	O
# in	O
# dogs	O
# with	O
# and	O
# without	O
# beta receptor	O
#
# magnesium s	O
# direct	O
# effect	O
# on	O
# calcium	O
# and	O
# potassium	O
# fluxes	O
# across	O
# the	O
# myocardial	O
# cell	O
# membrane	O
# may	O
# be	O
# the	O
# mechanism	O
# of	O
# its	O
# antiarrhythmic	O
# action	O
# in	O
# digitalis	B-plant
# toxic	O
# arrhythmias	B-disease
#
# inhibitory	O
# effect	O
# of	O
# green	B-plant
# tea	I-plant
# on	O
# the	O
# growth	O
# of	O
# established	O
# skin	B-disease
# papillomas	I-disease
# in	O
#
# in	O
# 10	O
# separate	O
# experiments	O
# mice	O
# with	O
# established	O
# chemically	O
# induced	O
# or	O
# uv	O
# light induced	O
# skin	B-disease
# papillomas	I-disease
# were	O
# treated	O
# ...

# %% [markdown]
# ### **Splitting `BIO dataset` into BIO `train`, `test`, `dev`**

# %%
! python "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/_process_data/splitting.py"

# %%
! ls -lh "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/raw_data"
# Out:
# total 456K
# -rw------- 1 root root 125K Jun 26 04:37 dev.txt
# -rw------- 1 root root    0 Jun 22 19:42 __init__.py
# -rw------- 1 root root 4.1K Jun 26 03:35 process.py
# -rw------- 1 root root 131K Jun 26 04:37 test.txt
# -rw------- 1 root root 195K Jun 26 04:37 train.txt

# %% [markdown]
# ### **Read train bio dataset**

# %%
bio_train_dataset = open("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/raw_data/train.txt", "r")
print(bio_train_dataset.read())
# Out:
# material	O
# and	O
# methods	O
# in	O
# a	O
# double blind	O
# randomized	O
# placebo	O
# controlled	O
# trial	O
# 64	O
# women	O
# with	O
# long	O
# bone	B-disease
# fracture	I-disease
# 20 45	O
# years	O
# old	O
# were	O
# randomly	O
# allocated	O
# to	O
# receive	O
# 1	O
# one	O
# agnugol	O
# tablet	O
# 4	O
# mg	O
# dried	O
# fruit	O
# extract	O
# of	O
# vitex	B-plant
# agnus	I-plant
# castus	I-plant
# plus	O
# 250	O
# mg	O
# magnesium	O
# oxide	O
# vac	O
# mg	O
# group	O
# n	O
# 10	O
# 2	O
# one	O
# agnugol	O
# tablet	O
# plus	O
# placebo	O
# vac	O
# group	O
# n	O
# 15	O
# 3	O
# placebo	O
# plus	O
# 250	O
# mg	O
# magnesium	O
# oxide	O
# mg	O
# group	O
# n	O
# 12	O
# or	O
# 4	O
# placebo	O
# plus	O
# placebo	O
# placebo	O
# group	O
# n	O
# 14	O
# per	O
# day	O
# for	O
# 8	O
#
# effects	O
# of	O
# korean	O
# red	O
# ginseng	B-plant
# extracts	O
# on	O
# neural	B-disease
# tube	I-disease
# defects	I-disease
# and	O
# impairment	O
# of	O
# social	O
# interaction	O
# induced	O
# ...

# %% [markdown]
# ### **Splitting BIO dataset into Truncate train, test, dev**

# %%
! python "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/raw_data/process.py"

# %%
! ls -lh "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/mid_data"
# Out:
# total 1.5M
# -rw------- 1 root root 855K Jun 26 03:33 data_150_cut.txt
# -rw------- 1 root root 169K Jun 26 04:37 dev.json
# -rw------- 1 root root   27 Jun 26 04:37 labels.json
# -rw------- 1 root root   24 Jun 26 04:37 nor_ent2id.json
# -rw------- 1 root root 177K Jun 26 04:37 test.json
# -rw------- 1 root root 265K Jun 26 04:37 train.json

# %% [markdown]
# ### **Read labels**

# %%
labels_dataset = open("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/mid_data/nor_ent2id.json", "r")
print(labels_dataset.read())
# Out:
# {"O": 0, "B": 1, "I": 2}

# %% [markdown]
# ### **Read train truncate data**

# %%
truncate_dataset = open("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/mid_data/train.json", "r")
print(truncate_dataset.read())
# Out:
# [{"id": 0, "text": "material and methods in a double blind randomized placebo controlled trial 64 women with long bone fracture 20 45 years old were randomly allocated to receive 1 one agnugol tablet 4 mg dried fruit extract of vitex agnus castus plus 250 mg magnesium oxide vac mg group n 10 2 one agnugol tablet plus placebo vac group n 15 3 placebo plus 250 mg magnesium oxide mg group n 12 or 4 placebo plus placebo placebo group n 14 per day for 8", "labels": [["T0", "disease", 94, 98, "bone"], ["T1", "disease", 99, 107, "fracture"], ["T2", "plant", 208, 213, "vitex"], ["T3", "plant", 214, 219, "agnus"], ["T4", "plant", 220, 226, "castus"]]}, {"id": 1, "text": "effects of korean red ginseng extracts on neural tube defects and impairment of social interaction induced by prenatal exposure to valproic", "labels": [["T0", "plant", 22, 29, "ginseng"], ["T1", "disease", 42, 48, "neural"], ["T2", "disease", 49, 53, "tube"], ["T3", "disease", 54, 61, "defects"]]}, {"id": 2, "text": "purpose
# ...

# %% [markdown]
# # **Preprocess to NER Dataset Json and Excel data with truncate and pos tagging**

# %% [markdown]
# ## **Into json data**

# %%
! python "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/into_json_data.py"

# %%
! ls -lh "./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.json"
# Out:
# -rw------- 1 root root 443K Jun 26 04:37 ./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.json

# %%
ner_json_dataset = open("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.json", "r")
print(ner_json_dataset.read())
# Out:
# [{"id": 0, "text": "studies on magnesium s mechanism of action in digitalis induced arrhythmias", "labels": [["T0", "plant", 46, 55, "digitalis"], ["T1", "disease", 64, 75, "arrhythmias"]]}, {"id": 1, "text": "the mechanism by which magnesium affects digitalis induced arrhythmias was studied in dogs with and without beta receptor", "labels": [["T0", "plant", 41, 50, "digitalis"], ["T1", "disease", 59, 70, "arrhythmias"]]}, {"id": 2, "text": "magnesium s direct effect on calcium and potassium fluxes across the myocardial cell membrane may be the mechanism of its antiarrhythmic action in digitalis toxic arrhythmias", "labels": [["T0", "plant", 147, 156, "digitalis"], ["T1", "disease", 163, 174, "arrhythmias"]]}, {"id": 3, "text": "inhibitory effect of green tea on the growth of established skin papillomas in", "labels": [["T0", "plant", 21, 26, "green"], ["T1", "plant", 27, 30, "tea"], ["T2", "disease", 60, 64, "skin"], ["T3", "disease", 65, 75, "papillomas"]]}, {"id": 4, "text": "in 1
# ...

# %% [markdown]
# ## **Into excel data**

# %%
! pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json

import pandas as pd
import xlsxwriter
import os
from collections import Counter
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
nltk.download('averaged_perceptron_tagger')

with open('./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.json', encoding='utf-8') as f:
    raw = json.load(f)

content_1 = []
content_2 = []
for i, item in enumerate(raw):
    text = item["text"]
    ids = item["id"]
    labels = item["labels"]

    labels_tags = []
    labels_word = []
    if len(labels) != 0:
        labels = [[label[0], label[2], label[3], label[4], label[1]] for label in labels]
        labels_word = [label[3] for label in labels]
        labels_tags = [label[4] for label in labels]

    texts = item["text"]
    lower_case = texts.lower()
    tokens = nltk.word_tokenize(lower_case)
    tags = nltk.pos_tag(tokens)
    counts = Counter(tag for word, tag in tags)

    tags_word = []
    tags_pos = []
    if len(tags) != 0:
        tags = [[pos_tag[0], pos_tag[1]] for pos_tag in tags]
        tags_word = [pos_tag[0] for pos_tag in tags]
        tags_pos = [pos_tag[1] for pos_tag in tags]

    print(tags)

    content_1.append([f"Sentence: {ids}", labels_word, labels_tags])
    content_2.append([f"Sentence: {ids}", tags_word, tags_pos])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [['studies', 'NNS'], ['on', 'IN'], ['magnesium', 'NN'], ['s', 'NN'], ['mechanism', 'NN'], ['of', 'IN'], ['action', 'NN'], ['in', 'IN'], ['digitalis', 'NN'], ['induced', 'VBD'], ['arrhythmias', 'NNS']]
# ...

# %%
df_labels = pd.DataFrame(content_1, columns=['Sentence #','Word', 'Tag']).explode(['Word', 'Tag'])
writer = pd.ExcelWriter('./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_labels.xlsx', engine='xlsxwriter')
df_labels.to_excel(writer, sheet_name='Sheet1', index=False)
writer.save()

# %%
data_labels = pd.read_excel("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_labels.xlsx")

# %%
data_labels.head()
# Out:
#     Sentence #         Word      Tag
# 0  Sentence: 0    digitalis    plant
# 1  Sentence: 0  arrhythmias  disease
# 2  Sentence: 1    digitalis    plant
# 3  Sentence: 1  arrhythmias  disease
# 4  Sentence: 2    digitalis    plant

# %%
data_labels.tail()
# Out:
#           Sentence #           Word      Tag
# 4647  Sentence: 1308  schizophrenia  disease
# 4648  Sentence: 1308       cannabis    plant
# 4649  Sentence: 1309       cannabis    plant
# 4650  Sentence: 1309  schizophrenia  disease
# 4651  Sentence: 1309       cannabis    plant

# %%
data_labels.shape
# Out:
# (4652, 3)

# %%
df_tags = pd.DataFrame(content_2, columns=['Sentence #', 'Word', 'POS']).explode(['Word', 'POS'])
writer = pd.ExcelWriter('./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_tags.xlsx', engine='xlsxwriter')
df_tags.to_excel(writer, sheet_name='Sheet1', index=False)
writer.save()

# %%
data_tags = pd.read_excel("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_tags.xlsx")

# %%
data_tags.head()
# Out:
#     Sentence #       Word  POS
# 0  Sentence: 0    studies  NNS
# 1  Sentence: 0         on   IN
# 2  Sentence: 0  magnesium   NN
# 3  Sentence: 0          s   NN
# 4  Sentence: 0  mechanism   NN

# %%
data_tags.tail()
# Out:
#            Sentence #     Word  POS
# 36351  Sentence: 1309      due   JJ
# 36352  Sentence: 1309       to   TO
# 36353  Sentence: 1309        a   DT
# 36354  Sentence: 1309   shared  VBN
# 36355  Sentence: 1309  genetic   JJ

# %%
data_tags.shape
# Out:
# (36356, 3)

# %%
join_data = pd.merge(data_tags, data_labels, how='left', on=['Sentence #', 'Word'])

# %%
join_data = join_data.fillna("O")

# %%
join_data.head()
# Out:
#     Sentence #       Word  POS Tag
# 0  Sentence: 0    studies  NNS   O
# 1  Sentence: 0         on   IN   O
# 2  Sentence: 0  magnesium   NN   O
# 3  Sentence: 0          s   NN   O
# 4  Sentence: 0  mechanism   NN   O

# %%
join_data.tail()
# Out:
#            Sentence #     Word  POS Tag
# 38200  Sentence: 1309      due   JJ   O
# 38201  Sentence: 1309       to   TO   O
# 38202  Sentence: 1309        a   DT   O
# 38203  Sentence: 1309   shared  VBN   O
# 38204  Sentence: 1309  genetic   JJ   O

# %%
join_data.shape
# Out:
# (38205, 4)

# %%
join_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38205 entries, 0 to 38204
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sentence #  38205 non-null  object
#  1   Word        38205 non-null  object
#  2   POS         38205 non-null  object
#  3   Tag         38205 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %%
join_data.dtypes
# Out:
# Sentence #    object
# Word          object
# POS           object
# Tag           object
# dtype: object

# %%
join_data.describe()
# Out:
#            Sentence #   Word    POS    Tag
# count           38205  38205  38205  38205
# unique           1310   3089     32      3
# top     Sentence: 264    and     NN      O
# freq              137   1704  11655  32002

# %%
join_data.to_excel('./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.xlsx', index=False)

# %%
ner_excel_dataset = pd.read_excel('./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/excel_data/ner_dataset.xlsx')

# %% [markdown]
# # **Read NER Dataset**

# %%
ner_excel_dataset.head()
# Out:
#     Sentence #       Word  POS Tag
# 0  Sentence: 0    studies  NNS   O
# 1  Sentence: 0         on   IN   O
# 2  Sentence: 0  magnesium   NN   O
# 3  Sentence: 0          s   NN   O
# 4  Sentence: 0  mechanism   NN   O

# %%
ner_excel_dataset.tail()
# Out:
#            Sentence #     Word  POS Tag
# 38200  Sentence: 1309      due   JJ   O
# 38201  Sentence: 1309       to   TO   O
# 38202  Sentence: 1309        a   DT   O
# 38203  Sentence: 1309   shared  VBN   O
# 38204  Sentence: 1309  genetic   JJ   O

# %%
ner_excel_dataset.to_csv("./drive/MyDrive/bert_bilstm_crf_named_entity_recognition/BERT-BILSTM-CRF-NER/input/ner_dataset.csv", index=None, header=True)

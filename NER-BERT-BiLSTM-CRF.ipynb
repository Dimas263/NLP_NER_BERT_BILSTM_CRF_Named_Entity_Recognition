# %% [markdown]
# # <img src="https://img.icons8.com/external-flaticons-lineal-color-flat-icons/64/undefined/external-big-data-smart-technology-flaticons-lineal-color-flat-icons-2.png"/> **NLP Research<br>BERT BiLSTM CRF Named Entity Recognition**
# ## <img src="https://img.icons8.com/external-smashingstocks-flat-smashing-stocks/64/000000/external-manager-hotel-smashingstocks-flat-smashing-stocks-2.png"/> **`Slamet Riyanto S.Kom., M.M.S.I.`**
# ## <img src="https://img.icons8.com/external-fauzidea-flat-fauzidea/64/undefined/external-man-avatar-avatar-fauzidea-flat-fauzidea.png"/> **`Dimas Dwi Putra`**

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/000000/google-drive--v1.png"/> Connect Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # <img src="https://img.icons8.com/color/48/000000/python--v1.png"/> Requirements Python Library

# %%
! pip install transformers==4.4.0
! pip install pickle5==0.0.12
! pip install pytorch-crf -i https://pypi.tuna.tsinghua.edu.cn/simple/
! pip install tensorflow-gpu
! pip install --upgrade h5py
! pip install tensorboardX
! pip install seqeval==0.0.2
! pip3 install torch==1.6.0 torchvision==0.7.0 -f https://download.pytorch.org/whl/cu101/torch_stable.html

# %% [markdown]
# # <img src="https://img.icons8.com/office/48/000000/database.png"/> NER Plant-Disease Dataset

# %%
import json

json.load(open("/content/drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/mid_data/train.json"))

# %% [markdown]
# # <img src="https://img.icons8.com/fluency/48/000000/source-code.png"/> Preprocessing Dataset To Bert Embedding, Tokens, and Sequence Tagging

# %%
! python ./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/preprocess.py \
--bert_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/model/biobert-plant-disease/ \
--data_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/ \
--log_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/logs/ \
--output_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/ \
--bio_tags=3 \
--att_tags=2 \
--seed=123 \
--gpu_ids="0" \
--max_seq_len=150 \
--lr=3e-5 \
--crf_lr=3e-2 \
--other_lr=3e-4 \
--train_batch_size=2 \
--train_epochs=50 \
--eval_batch_size=1 \
--max_grad_norm=1 \
--warmup_proportion=0.1 \
--adam_epsilon=1e-8 \
--weight_decay=0.01 \
--lstm_hidden=128 \
--num_layers=1 \
--use_lstm='True' \
--use_crf='True' \
--dropout_prob=0.1 \
--dropout=0.1

# %% [markdown]
# # <img src="https://img.icons8.com/fluency/48/000000/source-code.png"/> BERT NER

# %%
! python ./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/main.py \
--bert_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/model/biobert-plant-disease/ \
--data_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/ \
--log_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/logs/ \
--output_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/ \
--bio_tags=3 \
--att_tags=2 \
--seed=123 \
--gpu_ids="0" \
--max_seq_len=150 \
--lr=3e-5 \
--crf_lr=3e-2 \
--other_lr=3e-4 \
--train_batch_size=2 \
--train_epochs=10 \
--eval_batch_size=1 \
--max_grad_norm=1 \
--warmup_proportion=0.1 \
--adam_epsilon=1e-8 \
--weight_decay=0.01 \
--lstm_hidden=128 \
--num_layers=1 \
--use_lstm='True' \
--use_crf='True' \
--dropout_prob=0.1 \
--dropout=0.1

# %% [markdown]
# # <img src="https://img.icons8.com/fluency/48/000000/source-code.png"/> BERT-CRF NER

# %%
! python ./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/main.py \
--bert_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/model/biobert-plant-disease/ \
--data_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/ \
--log_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/logs/ \
--output_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/ \
--bio_tags=3 \
--att_tags=2 \
--seed=123 \
--gpu_ids="0" \
--max_seq_len=150 \
--lr=3e-5 \
--crf_lr=3e-2 \
--other_lr=3e-4 \
--train_batch_size=2 \
--train_epochs=10 \
--eval_batch_size=1 \
--max_grad_norm=1 \
--warmup_proportion=0.1 \
--adam_epsilon=1e-8 \
--weight_decay=0.01 \
--lstm_hidden=128 \
--num_layers=1 \
--use_lstm='True' \
--use_crf='True' \
--dropout_prob=0.1 \
--dropout=0.1

# %% [markdown]
# # <img src="https://img.icons8.com/fluency/48/000000/source-code.png"/> BERT-BI-LSTM NER

# %%
! python ./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/main.py \
--bert_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/model/biobert-plant-disease/ \
--data_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/ \
--log_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/logs/ \
--output_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/ \
--bio_tags=3 \
--att_tags=2 \
--seed=123 \
--gpu_ids="0" \
--max_seq_len=150 \
--lr=3e-5 \
--crf_lr=3e-2 \
--other_lr=3e-4 \
--train_batch_size=2 \
--train_epochs=10 \
--eval_batch_size=1 \
--max_grad_norm=1 \
--warmup_proportion=0.1 \
--adam_epsilon=1e-8 \
--weight_decay=0.01 \
--lstm_hidden=128 \
--num_layers=1 \
--use_lstm='True' \
--use_crf='True' \
--dropout_prob=0.1 \
--dropout=0.1

# %% [markdown]
# # <img src="https://img.icons8.com/fluency/48/000000/source-code.png"/> BERT-BI-LSTM-CRF NER

# %%
! python ./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/main.py \
--bert_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/model/biobert-plant-disease/ \
--data_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/input/ \
--log_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/logs/ \
--output_dir=./drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/ \
--bio_tags=3 \
--att_tags=2 \
--seed=123 \
--gpu_ids="0" \
--max_seq_len=150 \
--lr=3e-5 \
--crf_lr=3e-2 \
--other_lr=3e-4 \
--train_batch_size=2 \
--train_epochs=10 \
--eval_batch_size=1 \
--max_grad_norm=1 \
--warmup_proportion=0.1 \
--adam_epsilon=1e-8 \
--weight_decay=0.01 \
--lstm_hidden=128 \
--num_layers=1 \
--use_lstm='True' \
--use_crf='True' \
--dropout_prob=0.1 \
--dropout=0.1

# %% [markdown]
# # <img src="https://img.icons8.com/external-sbts2018-flat-sbts2018/48/000000/external-model-basic-ui-elements-2.4-sbts2018-flat-sbts2018.png"/> **Model Output**

# %%
! ls -lh "/content/drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/bert_bilstm_crf"

# %%
import torch

models = torch.load("/content/drive/MyDrive/Rearch_Dimas/BERT-BILSTM-CRF-NER/output/checkpoints/bert_bilstm_crf/model.pt")
models
